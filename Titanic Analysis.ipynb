# %% [markdown]
# Basic Questions
#
#     1.) Who were the passengers on the Titanic? (Age, Gender, Class,.. etc)
#     2.) What deck were the passengers on and how does that relate to their class?
#     3.) Where did the passenger came from?
#     4.) Who was alone and who was with family?
#
# Digging Deeper
#
#     5.) What factors helped someone survive the sinking?

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Set up the Titainc csv file as a DataFrame
titanic_df = pd.read_csv('train.csv')

# %%
#Preview it
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Overall information about the dataset
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.catplot(x='Sex',data=titanic_df,kind="count")

# %%
# Indicate number of male and female in each passenger class

sns.catplot(x='Sex',data=titanic_df,kind="count",hue='Pclass')

# %%
sns.catplot(x='Pclass',data=titanic_df,kind="count",hue='Sex')

# %%
def male_female_child(passenger):
    age,sex = passenger
    
    if age < 16:
        return 'child'
    else:
        return sex

# %%
titanic_df['person'] = titanic_df[['Age','Sex']].apply(male_female_child,axis=1)

# %%
titanic_df[0:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male
# 5      0            330877   8.4583   NaN        Q    male
# 6      0             17463  51.8625   E46        S    male
# 7      1            349909  21.0750   NaN        S   child
# 8      2            347742  11.1333   NaN        S  female
# 9      0            237736  30.0708   NaN        C   child

# %%
sns.catplot(data=titanic_df,x="Pclass",hue='person',kind="count")

# %%
titanic_df['Age'].hist(bins=70)
# Out:
# <Axes: >

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_df['person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
figure = sns.FacetGrid(titanic_df,hue='Sex',aspect=4)

figure.map(sns.kdeplot,'Age',fill=True)

oldest = titanic_df['Age'].max()

figure.set(xlim=(0,oldest))

figure.add_legend()

# %%
figure = sns.FacetGrid(titanic_df,hue='person',aspect=4)

figure.map(sns.kdeplot,'Age',fill=True)

oldest = titanic_df['Age'].max()

figure.set(xlim=(0,oldest))

figure.add_legend()

# %%
figure = sns.FacetGrid(titanic_df,hue='Pclass',aspect=4)

figure.map(sns.kdeplot,'Age',fill=True)

oldest = titanic_df['Age'].max()

figure.set(xlim=(0,oldest))

figure.add_legend()

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male

# %% [markdown]
# 2.) What deck were the passengers on and how does that relate to their class?

# %%
deck = titanic_df['Cabin'].dropna()

# %%
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels = []

for level in deck:
    levels.append(level[0])
    
    
cabin_df = DataFrame(levels)

cabin_df.columns = ['Cabin']

sns.catplot(data=cabin_df,x='Cabin',palette='winter_d',kind='count')

# %%
cabin_df = cabin_df[cabin_df.Cabin != 'T']

# %%
sns.catplot(data=cabin_df,x='Cabin',palette='flare',kind='count',order=['A','B','C','D','E','F','G'])

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male

# %% [markdown]
# 3.) Where did the passenger came from?

# %%
sns.catplot(data=titanic_df,x='Embarked', hue='Pclass', kind='count')

# %% [markdown]
# 4.) Who was alone and who was with family?

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male

# %%
# adding a column "Alone" for passengers who were along

titanic_df['Alone temp'] = titanic_df.SibSp + titanic_df.Parch

titanic_df['Alone temp']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Name: Alone temp, Length: 891, dtype: int64

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  person  Alone temp
# 0        0         A/5 21171   7.2500   NaN        S    male           1
# 1        0          PC 17599  71.2833   C85        C  female           1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  female           0
# 3        0            113803  53.1000  C123        S  female           1
# 4        0            373450   8.0500   NaN        S    male           0
# ..     ...               ...      ...   ...      ...     ...         ...
# 886      0            211536  13.0000   NaN        S    male           0
# 887      0            112053  30.0000   B42        S  female           0
# 888      2        W./C. 6607  23.4500   NaN        S  female           3
# 889      0            111369  30.0000  C148        C    male           0
# 890      0            370376   7.7500   NaN        Q    male           0
#
# [891 rows x 14 columns]

# %%
#function that return "Alone" with family of 0 else "with family"
def alone_and_family(alone):
    if (alone == 0):
        return 'Alone'
    else:
        return 'With Family'

# %%
#applying the function "alone_and_family"
titanic_df['Alone'] = titanic_df['Alone temp'].apply(alone_and_family)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  person  Alone temp  \
# 0        0         A/5 21171   7.2500   NaN        S    male           1
# 1        0          PC 17599  71.2833   C85        C  female           1
# 2        0  STON/O2. 3101282   7.9250   NaN        S  female           0
# 3        0            113803  53.1000  C123        S  female           1
# 4        0            373450   8.0500   NaN        S    male           0
# ..     ...               ...      ...   ...      ...     ...         ...
# 886      0            211536  13.0000   NaN        S    male           0
# 887      0            112053  30.0000   B42        S  female           0
# 888      2        W./C. 6607  23.4500   NaN        S  female           3
# 889      0            111369  30.0000  C148        C    male           0
# 890      0            370376   7.7500   NaN        Q    male           0
#
#            Alone
# 0    With Family
# 1    With Family
# 2          Alone
# 3    With Family
# 4          Alone
# ..           ...
# 886        Alone
# 887        Alone
# 888  With Family
# 889        Alone
# 890        Alone
#
# [891 rows x 15 columns]

# %%
# dropping temporary column
titanic_df.drop(columns='Alone temp')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  person        Alone
# 0        0         A/5 21171   7.2500   NaN        S    male  With Family
# 1        0          PC 17599  71.2833   C85        C  female  With Family
# 2        0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# 3        0            113803  53.1000  C123        S  female  With Family
# 4        0            373450   8.0500   NaN        S    male        Alone
# ..     ...               ...      ...   ...      ...     ...          ...
# 886      0            211536  13.0000   NaN        S    male        Alone
# 887      0            112053  30.0000   B42        S  female        Alone
# 888      2        W./C. 6607  23.4500   NaN        S  female  With Family
# 889      0            111369  30.0000  C148        C    male        Alone
# 890      0            370376   7.7500   NaN        Q    male        Alone
#
# [891 rows x 14 columns]

# %%
sns.countplot(data=titanic_df,x="Alone")
# Out:
# <Axes: xlabel='Alone', ylabel='count'>

# %% [markdown]
# 5.) What factors helped someone survive the sinking?

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person  Alone temp  \
# 0      0         A/5 21171   7.2500   NaN        S    male           1
# 1      0          PC 17599  71.2833   C85        C  female           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female           0
# 3      0            113803  53.1000  C123        S  female           1
# 4      0            373450   8.0500   NaN        S    male           0
#
#          Alone
# 0  With Family
# 1  With Family
# 2        Alone
# 3  With Family
# 4        Alone

# %%
# people who survied i.e "1" are set as yes else they are marked "no"
titanic_df["Survivor"] = titanic_df.Survived.map({0:"no",1:"yes"})

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person  Alone temp  \
# 0      0         A/5 21171   7.2500   NaN        S    male           1
# 1      0          PC 17599  71.2833   C85        C  female           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female           0
# 3      0            113803  53.1000  C123        S  female           1
# 4      0            373450   8.0500   NaN        S    male           0
#
#          Alone Survivor
# 0  With Family       no
# 1  With Family      yes
# 2        Alone      yes
# 3  With Family      yes
# 4        Alone       no

# %%
sns.countplot(data=titanic_df,x='Survivor')
# Out:
# <Axes: xlabel='Survivor', ylabel='count'>

# %%
sns.countplot(data=titanic_df,x='Survivor',hue='Pclass')
# Out:
# <Axes: xlabel='Survivor', ylabel='count'>

# %%
sns.catplot(data=titanic_df,y='Survived',x='Pclass',hue='person',kind='point')

# %%
sns.lmplot(data=titanic_df,x='Age',y='Survived')

# %%
sns.lmplot(data=titanic_df,x='Age',y='Survived',hue='Pclass',palette='winter')
